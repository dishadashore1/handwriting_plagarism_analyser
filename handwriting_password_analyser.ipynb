# %% [markdown]
# <a href="https://colab.research.google.com/github/dishadashore1/handwriting_plagarism_analyser/blob/main/handwriting_password_analyser.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
